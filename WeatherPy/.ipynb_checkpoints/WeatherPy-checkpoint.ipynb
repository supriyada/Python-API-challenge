# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy.stats import pearsonr
from pprint import pprint
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'City count: {len(cities)}')
# Out:
# City count: 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api.openweathermap.org/data/2.5/find?q=London&units=imperial
url1 = "http://api.openweathermap.org/data/2.5/weather?"

query_url1 = url1 + "appid=" + weather_api_key + "&q=busselton" + "&units=imperial"
response1 = requests.get(query_url1).json()

pprint(response1)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

city_name = []
cloudiness = []
country = []
date1 = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_Speed = []
error_city = []

cnum = 1
for city in cities:
    print(f'The data of city with number: {cnum} and name: {city} is getting retreived')
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    response = requests.get(query_url).json()
    time.sleep(2)
    
    try:
        city_name.append(city)
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date1.append(response['dt'])
        humidity.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_Speed.append(response['wind']['speed'])
        print(f'The data of city with number: {cnum} and name: {city} is successfully retreived')   
    except:
        error_city.append(city)
        city_name.pop()
        print(f'The data of city with number: {cnum} and name: {city} is not found!\n Removing from the list')
    cnum +=1

print(f'\nThe weather data of {len(cities)} cities has been requested!\n')
print(f'The weather data for {len(error_city)} cities are not found!\n')
print(f'The weather data of {len(city_name)} cities has been successfully retrieved')
# Out:
# The data of city with number: 1 and name: punta arenas is getting retreived
# The data of city with number: 1 and name: punta arenas is successfully retreived
# The data of city with number: 2 and name: saint-philippe is getting retreived
# The data of city with number: 2 and name: saint-philippe is successfully retreived
# The data of city with number: 3 and name: kandrian is getting retreived
# The data of city with number: 3 and name: kandrian is successfully retreived
# The data of city with number: 4 and name: cidreira is getting retreived
# The data of city with number: 4 and name: cidreira is successfully retreived
# The data of city with number: 5 and name: mosquera is getting retreived
# The data of city with number: 5 and name: mosquera is successfully retreived
# The data of city with number: 6 and name: nordborg is getting retreived
# The data of city with number: 6 and name: nordborg is successfully retreived
# The data of city with number: 7 and name: taolanaro is getting retreived
# The data of city with number: 7 and name: taolanaro is not found!
#  Removing from the list
# The data of city with number: 8 and name: georgetown is getting retreived
# The data of city with number: 8 and name: georgetown is successfully retreived
# The data of city with number: 9 and name: butaritari is getting retreived
# The data of city with number: 9 and name: butaritari is successfully retreived
# The data of city with number: 10 and name: rikitea is getting retreived
# The data of city with number: 10 and name: rikitea is successfully retreived
# The data of city with number: 11 and name: ossora is getting retreived
# The data of city with number: 11 and name: ossora is successfully retreived
# The data of city with number: 12 and name: tiruvottiyur is getting retreived
# The data of city with number: 12 and name: tiruvottiyur is not found!
#  Removing from the list
# The data of city with number: 13 and name: upernavik is getting retreived
# The data of city with number: 13 and name: upernavik is successfully retreived
# The data of city with number: 14 and name: tuatapere is getting retreived
# The data of city with number: 14 and name: tuatapere is successfully retreived
# The data of city with number: 15 and name: tovste is getting retreived
# The data of city with number: 15 and name: tovste is successfully retreived
# The data of city with number: 16 and name: luderitz is getting retreived
# The data of city with number: 16 and name: luderitz is successfully retreived
# The data of city with number: 17 and name: hithadhoo is getting retreived
# The data of city with number: 17 and name: hithadhoo is successfully retreived
# The data of city with number: 18 and name: damaturu is getting retreived
# The data of city with number: 18 and name: damaturu is successfully retreived
# The data of city with number: 19 and name: balkhash is getting retreived
# The data of city with number: 19 and name: balkhash is successfully retreived
# The data of city with number: 20 and name: port alfred is getting retreived
# The data of city with number: 20 and name: port alfred is successfully retreived
# The data of city with number: 21 and name: tsihombe is getting retreived
# The data of city with number: 21 and name: tsihombe is not found!
#  Removing from the list
# The data of city with number: 22 and name: victoria is getting retreived
# The data of city with number: 22 and name: victoria is successfully retreived
# The data of city with number: 23 and name: airai is getting retreived
# The data of city with number: 23 and name: airai is successfully retreived
# The data of city with number: 24 and name: grand river south east is getting retreived
# The data of city with number: 24 and name: grand river south east is not found!
#  Removing from the list
# The data of city with number: 25 and name: hobart is getting retreived
# The data of city with number: 25 and name: hobart is successfully retreived
# The data of city with number: 26 and name: ewa beach is getting retreived
# The data of city with number: 26 and name: ewa beach is successfully retreived
# The data of city with number: 27 and name: pimenta bueno is getting retreived
# The data of city with number: 27 and name: pimenta bueno is successfully retreived
# The data of city with number: 28 and name: swidnica is getting retreived
# The data of city with number: 28 and name: swidnica is successfully retreived
# The data of city with number: 29 and name: arteaga is getting retreived
# The data of city with number: 29 and name: arteaga is successfully retreived
# The data of city with number: 30 and name: chapais is getting retreived
# The data of city with number: 30 and name: chapais is successfully retreived
# The data of city with number: 31 and name: port elizabeth is getting retreived
# The data of city with number: 31 and name: port elizabeth is successfully retreived
# The data of city with number: 32 and name: bodden town is getting retreived
# The data of city with number: 32 and name: bodden town is successfully retreived
# The data of city with number: 33 and name: harper is getting retreived
# The data of city with number: 33 and name: harper is successfully retreived
# The data of city with number: 34 and name: bengkulu is getting retreived
# The data of city with number: 34 and name: bengkulu is successfully retreived
# The data of city with number: 35 and name: broome is getting retreived
# The data of city with number: 35 and name: broome is successfully retreived
# The data of city with number: 36 and name: nguiu is getting retreived
# The data of city with number: 36 and name: nguiu is not found!
#  Removing from the list
# The data of city with number: 37 and name: ribeira grande is getting retreived
# The data of city with number: 37 and name: ribeira grande is successfully retreived
# The data of city with number: 38 and name: salair is getting retreived
# The data of city with number: 38 and name: salair is successfully retreived
# The data of city with number: 39 and name: bredasdorp is getting retreived
# The data of city with number: 39 and name: bredasdorp is successfully retreived
# The data of city with number: 40 and name: noshiro is getting retreived
# The data of city with number: 40 and name: noshiro is successfully retreived
# The data of city with number: 41 and name: huizhou is getting retreived
# The data of city with number: 41 and name: huizhou is successfully retreived
# The data of city with number: 42 and name: kruisfontein is getting retreived
# The data of city with number: 42 and name: kruisfontein is successfully retreived
# The data of city with number: 43 and name: vaini is getting retreived
# The data of city with number: 43 and name: vaini is successfully retreived
# The data of city with number: 44 and name: mataura is getting retreived
# The data of city with number: 44 and name: mataura is successfully retreived
# The data of city with number: 45 and name: ilo is getting retreived
# The data of city with number: 45 and name: ilo is successfully retreived
# The data of city with number: 46 and name: varkaus is getting retreived
# The data of city with number: 46 and name: varkaus is successfully retreived
# The data of city with number: 47 and name: mwingi is getting retreived
# The data of city with number: 47 and name: mwingi is successfully retreived
# The data of city with number: 48 and name: new norfolk is getting retreived
# The data of city with number: 48 and name: new norfolk is successfully retreived
# The data of city with number: 49 and name: maceio is getting retreived
# The data of city with number: 49 and name: maceio is successfully retreived
# The data of city with number: 50 and name: litoral del san juan is getting retreived
# The data of city with number: 50 and name: litoral del san juan is not found!
#  Removing from the list
# The data of city with number: 51 and name: kaeo is getting retreived
# The data of city with number: 51 and name: kaeo is successfully retreived
# The data of city with number: 52 and name: najran is getting retreived
# The data of city with number: 52 and name: najran is successfully retreived
# The data of city with number: 53 and name: khatanga is getting retreived
# The data of city with number: 53 and name: khatanga is successfully retreived
# The data of city with number: 54 and name: tolaga bay is getting retreived
# The data of city with number: 54 and name: tolaga bay is successfully retreived
# The data of city with number: 55 and name: tiksi is getting retreived
# The data of city with number: 55 and name: tiksi is successfully retreived
# The data of city with number: 56 and name: hermanus is getting retreived
# The data of city with number: 56 and name: hermanus is successfully retreived
# The data of city with number: 57 and name: yulara is getting retreived
# The data of city with number: 57 and name: yulara is successfully retreived
# The data of city with number: 58 and name: aksarka is getting retreived
# The data of city with number: 58 and name: aksarka is successfully retreived
# The data of city with number: 59 and name: qasigiannguit is getting retreived
# The data of city with number: 59 and name: qasigiannguit is successfully retreived
# The data of city with number: 60 and name: dingle is getting retreived
# The data of city with number: 60 and name: dingle is successfully retreived
# The data of city with number: 61 and name: hilo is getting retreived
# The data of city with number: 61 and name: hilo is successfully retreived
# The data of city with number: 62 and name: arraial do cabo is getting retreived
# The data of city with number: 62 and name: arraial do cabo is successfully retreived
# The data of city with number: 63 and name: bacuit is getting retreived
# The data of city with number: 63 and name: bacuit is not found!
#  Removing from the list
# The data of city with number: 64 and name: ahipara is getting retreived
# The data of city with number: 64 and name: ahipara is successfully retreived
# The data of city with number: 65 and name: basavana bagevadi is getting retreived
# The data of city with number: 65 and name: basavana bagevadi is successfully retreived
# The data of city with number: 66 and name: bluff is getting retreived
# The data of city with number: 66 and name: bluff is successfully retreived
# The data of city with number: 67 and name: mar del plata is getting retreived
# The data of city with number: 67 and name: mar del plata is successfully retreived
# The data of city with number: 68 and name: thompson is getting retreived
# The data of city with number: 68 and name: thompson is successfully retreived
# The data of city with number: 69 and name: pevek is getting retreived
# The data of city with number: 69 and name: pevek is successfully retreived
# The data of city with number: 70 and name: wanning is getting retreived
# The data of city with number: 70 and name: wanning is successfully retreived
# The data of city with number: 71 and name: klaksvik is getting retreived
# The data of city with number: 71 and name: klaksvik is successfully retreived
# The data of city with number: 72 and name: ushuaia is getting retreived
# The data of city with number: 72 and name: ushuaia is successfully retreived
# The data of city with number: 73 and name: inhambane is getting retreived
# The data of city with number: 73 and name: inhambane is successfully retreived
# The data of city with number: 74 and name: seydi is getting retreived
# The data of city with number: 74 and name: seydi is successfully retreived
# The data of city with number: 75 and name: port blair is getting retreived
# The data of city with number: 75 and name: port blair is successfully retreived
# The data of city with number: 76 and name: storforshei is getting retreived
# The data of city with number: 76 and name: storforshei is successfully retreived
# The data of city with number: 77 and name: betera is getting retreived
# The data of city with number: 77 and name: betera is successfully retreived
# The data of city with number: 78 and name: derzhavinsk is getting retreived
# The data of city with number: 78 and name: derzhavinsk is successfully retreived
# The data of city with number: 79 and name: atuona is getting retreived
# The data of city with number: 79 and name: atuona is successfully retreived
# The data of city with number: 80 and name: belushya guba is getting retreived
# The data of city with number: 80 and name: belushya guba is not found!
#  Removing from the list
# The data of city with number: 81 and name: kapaa is getting retreived
# The data of city with number: 81 and name: kapaa is successfully retreived
# The data of city with number: 82 and name: alcaniz is getting retreived
# The data of city with number: 82 and name: alcaniz is successfully retreived
# The data of city with number: 83 and name: rosetta is getting retreived
# The data of city with number: 83 and name: rosetta is successfully retreived
# The data of city with number: 84 and name: leningradskiy is getting retreived
# The data of city with number: 84 and name: leningradskiy is successfully retreived
# The data of city with number: 85 and name: tilichiki is getting retreived
# The data of city with number: 85 and name: tilichiki is successfully retreived
# The data of city with number: 86 and name: dalby is getting retreived
# The data of city with number: 86 and name: dalby is successfully retreived
# The data of city with number: 87 and name: la asuncion is getting retreived
# The data of city with number: 87 and name: la asuncion is successfully retreived
# The data of city with number: 88 and name: camacha is getting retreived
# The data of city with number: 88 and name: camacha is successfully retreived
# The data of city with number: 89 and name: chuy is getting retreived
# The data of city with number: 89 and name: chuy is successfully retreived
# The data of city with number: 90 and name: hami is getting retreived
# The data of city with number: 90 and name: hami is successfully retreived
# The data of city with number: 91 and name: faanui is getting retreived
# The data of city with number: 91 and name: faanui is successfully retreived
# The data of city with number: 92 and name: perelyub is getting retreived
# The data of city with number: 92 and name: perelyub is successfully retreived
# The data of city with number: 93 and name: saleaula is getting retreived
# The data of city with number: 93 and name: saleaula is not found!
#  Removing from the list
# The data of city with number: 94 and name: yellowknife is getting retreived
# The data of city with number: 94 and name: yellowknife is successfully retreived
# The data of city with number: 95 and name: busselton is getting retreived
# The data of city with number: 95 and name: busselton is successfully retreived
# The data of city with number: 96 and name: saskylakh is getting retreived
# The data of city with number: 96 and name: saskylakh is successfully retreived
# The data of city with number: 97 and name: nome is getting retreived
# The data of city with number: 97 and name: nome is successfully retreived
# The data of city with number: 98 and name: nyurba is getting retreived
# The data of city with number: 98 and name: nyurba is successfully retreived
# The data of city with number: 99 and name: tasiilaq is getting retreived
# The data of city with number: 99 and name: tasiilaq is successfully retreived
# The data of city with number: 100 and name: bamnet narong is getting retreived
# The data of city with number: 100 and name: bamnet narong is successfully retreived
# The data of city with number: 101 and name: ngukurr is getting retreived
# The data of city with number: 101 and name: ngukurr is not found!
#  Removing from the list
# The data of city with number: 102 and name: veraval is getting retreived
# The data of city with number: 102 and name: veraval is successfully retreived
# The data of city with number: 103 and name: marsh harbour is getting retreived
# The data of city with number: 103 and name: marsh harbour is successfully retreived
# The data of city with number: 104 and name: klyuchi is getting retreived
# The data of city with number: 104 and name: klyuchi is successfully retreived
# The data of city with number: 105 and name: cherskiy is getting retreived
# The data of city with number: 105 and name: cherskiy is successfully retreived
# The data of city with number: 106 and name: puerto carreno is getting retreived
# The data of city with number: 106 and name: puerto carreno is successfully retreived
# The data of city with number: 107 and name: ancud is getting retreived
# The data of city with number: 107 and name: ancud is successfully retreived
# The data of city with number: 108 and name: puerto suarez is getting retreived
# The data of city with number: 108 and name: puerto suarez is successfully retreived
# The data of city with number: 109 and name: along is getting retreived
# The data of city with number: 109 and name: along is successfully retreived
# The data of city with number: 110 and name: mys shmidta is getting retreived
# The data of city with number: 110 and name: mys shmidta is not found!
#  Removing from the list
# The data of city with number: 111 and name: guadalupe victoria is getting retreived
# The data of city with number: 111 and name: guadalupe victoria is successfully retreived
# The data of city with number: 112 and name: aracaju is getting retreived
# The data of city with number: 112 and name: aracaju is successfully retreived
# The data of city with number: 113 and name: lansdale is getting retreived
# The data of city with number: 113 and name: lansdale is successfully retreived
# The data of city with number: 114 and name: xingyi is getting retreived
# The data of city with number: 114 and name: xingyi is successfully retreived
# The data of city with number: 115 and name: port hardy is getting retreived
# The data of city with number: 115 and name: port hardy is successfully retreived
# The data of city with number: 116 and name: mitsamiouli is getting retreived
# The data of city with number: 116 and name: mitsamiouli is successfully retreived
# The data of city with number: 117 and name: attawapiskat is getting retreived
# The data of city with number: 117 and name: attawapiskat is not found!
#  Removing from the list
# The data of city with number: 118 and name: mugumu is getting retreived
# The data of city with number: 118 and name: mugumu is successfully retreived
# The data of city with number: 119 and name: samarai is getting retreived
# The data of city with number: 119 and name: samarai is successfully retreived
# The data of city with number: 120 and name: tiarei is getting retreived
# The data of city with number: 120 and name: tiarei is successfully retreived
# The data of city with number: 121 and name: sola is getting retreived
# The data of city with number: 121 and name: sola is successfully retreived
# The data of city with number: 122 and name: honiara is getting retreived
# The data of city with number: 122 and name: honiara is successfully retreived
# The data of city with number: 123 and name: kavieng is getting retreived
# The data of city with number: 123 and name: kavieng is successfully retreived
# The data of city with number: 124 and name: castro is getting retreived
# The data of city with number: 124 and name: castro is successfully retreived
# The data of city with number: 125 and name: nabire is getting retreived
# The data of city with number: 125 and name: nabire is successfully retreived
# The data of city with number: 126 and name: ostrovnoy is getting retreived
# The data of city with number: 126 and name: ostrovnoy is successfully retreived
# The data of city with number: 127 and name: clyde river is getting retreived
# The data of city with number: 127 and name: clyde river is successfully retreived
# The data of city with number: 128 and name: cumra is getting retreived
# The data of city with number: 128 and name: cumra is successfully retreived
# The data of city with number: 129 and name: saint-augustin is getting retreived
# The data of city with number: 129 and name: saint-augustin is successfully retreived
# The data of city with number: 130 and name: esperance is getting retreived
# The data of city with number: 130 and name: esperance is successfully retreived
# The data of city with number: 131 and name: drummondville is getting retreived
# The data of city with number: 131 and name: drummondville is successfully retreived
# The data of city with number: 132 and name: saint-pierre is getting retreived
# The data of city with number: 132 and name: saint-pierre is successfully retreived
# The data of city with number: 133 and name: tuktoyaktuk is getting retreived
# The data of city with number: 133 and name: tuktoyaktuk is successfully retreived
# The data of city with number: 134 and name: khani is getting retreived
# The data of city with number: 134 and name: khani is successfully retreived
# The data of city with number: 135 and name: isangel is getting retreived
# The data of city with number: 135 and name: isangel is successfully retreived
# The data of city with number: 136 and name: illoqqortoormiut is getting retreived
# The data of city with number: 136 and name: illoqqortoormiut is not found!
#  Removing from the list
# The data of city with number: 137 and name: avarua is getting retreived
# The data of city with number: 137 and name: avarua is successfully retreived
# The data of city with number: 138 and name: cape town is getting retreived
# The data of city with number: 138 and name: cape town is successfully retreived
# The data of city with number: 139 and name: high level is getting retreived
# The data of city with number: 139 and name: high level is successfully retreived
# The data of city with number: 140 and name: lompoc is getting retreived
# The data of city with number: 140 and name: lompoc is successfully retreived
# The data of city with number: 141 and name: bethel is getting retreived
# The data of city with number: 141 and name: bethel is successfully retreived
# The data of city with number: 142 and name: rio gallegos is getting retreived
# The data of city with number: 142 and name: rio gallegos is successfully retreived
# The data of city with number: 143 and name: jamestown is getting retreived
# The data of city with number: 143 and name: jamestown is successfully retreived
# The data of city with number: 144 and name: qandala is getting retreived
# The data of city with number: 144 and name: qandala is successfully retreived
# The data of city with number: 145 and name: albany is getting retreived
# The data of city with number: 145 and name: albany is successfully retreived
# The data of city with number: 146 and name: ambovombe is getting retreived
# The data of city with number: 146 and name: ambovombe is successfully retreived
# The data of city with number: 147 and name: fukue is getting retreived
# The data of city with number: 147 and name: fukue is successfully retreived
# The data of city with number: 148 and name: sao joao da barra is getting retreived
# The data of city with number: 148 and name: sao joao da barra is successfully retreived
# The data of city with number: 149 and name: riyadh is getting retreived
# The data of city with number: 149 and name: riyadh is successfully retreived
# The data of city with number: 150 and name: mangan is getting retreived
# The data of city with number: 150 and name: mangan is successfully retreived
# The data of city with number: 151 and name: port-gentil is getting retreived
# The data of city with number: 151 and name: port-gentil is successfully retreived
# The data of city with number: 152 and name: nigde is getting retreived
# The data of city with number: 152 and name: nigde is successfully retreived
# The data of city with number: 153 and name: ginir is getting retreived
# The data of city with number: 153 and name: ginir is successfully retreived
# The data of city with number: 154 and name: sattahip is getting retreived
# The data of city with number: 154 and name: sattahip is successfully retreived
# The data of city with number: 155 and name: saint george is getting retreived
# The data of city with number: 155 and name: saint george is successfully retreived
# The data of city with number: 156 and name: ibotirama is getting retreived
# The data of city with number: 156 and name: ibotirama is successfully retreived
# The data of city with number: 157 and name: vila velha is getting retreived
# The data of city with number: 157 and name: vila velha is successfully retreived
# The data of city with number: 158 and name: tiznit is getting retreived
# The data of city with number: 158 and name: tiznit is successfully retreived
# The data of city with number: 159 and name: carutapera is getting retreived
# The data of city with number: 159 and name: carutapera is successfully retreived
# The data of city with number: 160 and name: sosua is getting retreived
# The data of city with number: 160 and name: sosua is successfully retreived
# The data of city with number: 161 and name: santa eulalia del rio is getting retreived
# The data of city with number: 161 and name: santa eulalia del rio is not found!
#  Removing from the list
# The data of city with number: 162 and name: omboue is getting retreived
# The data of city with number: 162 and name: omboue is successfully retreived
# The data of city with number: 163 and name: saint paul is getting retreived
# The data of city with number: 163 and name: saint paul is successfully retreived
# The data of city with number: 164 and name: port shepstone is getting retreived
# The data of city with number: 164 and name: port shepstone is successfully retreived
# The data of city with number: 165 and name: tabuk is getting retreived
# The data of city with number: 165 and name: tabuk is successfully retreived
# The data of city with number: 166 and name: uyo is getting retreived
# The data of city with number: 166 and name: uyo is successfully retreived
# The data of city with number: 167 and name: grand gaube is getting retreived
# The data of city with number: 167 and name: grand gaube is successfully retreived
# The data of city with number: 168 and name: phan rang is getting retreived
# The data of city with number: 168 and name: phan rang is not found!
#  Removing from the list
# The data of city with number: 169 and name: cabo san lucas is getting retreived
# The data of city with number: 169 and name: cabo san lucas is successfully retreived
# The data of city with number: 170 and name: dikson is getting retreived
# The data of city with number: 170 and name: dikson is successfully retreived
# The data of city with number: 171 and name: kodiak is getting retreived
# The data of city with number: 171 and name: kodiak is successfully retreived
# The data of city with number: 172 and name: kamenskoye is getting retreived
# The data of city with number: 172 and name: kamenskoye is not found!
#  Removing from the list
# The data of city with number: 173 and name: boshnyakovo is getting retreived
# The data of city with number: 173 and name: boshnyakovo is successfully retreived
# The data of city with number: 174 and name: nizhneyansk is getting retreived
# The data of city with number: 174 and name: nizhneyansk is not found!
#  Removing from the list
# The data of city with number: 175 and name: kaka is getting retreived
# The data of city with number: 175 and name: kaka is successfully retreived
# The data of city with number: 176 and name: anau is getting retreived
# The data of city with number: 176 and name: anau is successfully retreived
# The data of city with number: 177 and name: half moon bay is getting retreived
# The data of city with number: 177 and name: half moon bay is successfully retreived
# The data of city with number: 178 and name: kununurra is getting retreived
# The data of city with number: 178 and name: kununurra is successfully retreived
# The data of city with number: 179 and name: takoradi is getting retreived
# The data of city with number: 179 and name: takoradi is successfully retreived
# The data of city with number: 180 and name: nyuksenitsa is getting retreived
# The data of city with number: 180 and name: nyuksenitsa is successfully retreived
# The data of city with number: 181 and name: marsa matruh is getting retreived
# The data of city with number: 181 and name: marsa matruh is successfully retreived
# The data of city with number: 182 and name: qaanaaq is getting retreived
# The data of city with number: 182 and name: qaanaaq is successfully retreived
# The data of city with number: 183 and name: nishihara is getting retreived
# The data of city with number: 183 and name: nishihara is successfully retreived
# The data of city with number: 184 and name: myaundzha is getting retreived
# The data of city with number: 184 and name: myaundzha is successfully retreived
# The data of city with number: 185 and name: kaitangata is getting retreived
# The data of city with number: 185 and name: kaitangata is successfully retreived
# The data of city with number: 186 and name: beringovskiy is getting retreived
# The data of city with number: 186 and name: beringovskiy is successfully retreived
# The data of city with number: 187 and name: college is getting retreived
# The data of city with number: 187 and name: college is successfully retreived
# The data of city with number: 188 and name: kita is getting retreived
# The data of city with number: 188 and name: kita is successfully retreived
# The data of city with number: 189 and name: mrirt is getting retreived
# The data of city with number: 189 and name: mrirt is not found!
#  Removing from the list
# The data of city with number: 190 and name: chokurdakh is getting retreived
# The data of city with number: 190 and name: chokurdakh is successfully retreived
# The data of city with number: 191 and name: pinos is getting retreived
# The data of city with number: 191 and name: pinos is successfully retreived
# The data of city with number: 192 and name: vaitupu is getting retreived
# The data of city with number: 192 and name: vaitupu is not found!
#  Removing from the list
# The data of city with number: 193 and name: high rock is getting retreived
# The data of city with number: 193 and name: high rock is successfully retreived
# The data of city with number: 194 and name: ponta do sol is getting retreived
# The data of city with number: 194 and name: ponta do sol is successfully retreived
# The data of city with number: 195 and name: bundu is getting retreived
# The data of city with number: 195 and name: bundu is successfully retreived
# The data of city with number: 196 and name: palmer is getting retreived
# The data of city with number: 196 and name: palmer is successfully retreived
# The data of city with number: 197 and name: coquimbo is getting retreived
# The data of city with number: 197 and name: coquimbo is successfully retreived
# The data of city with number: 198 and name: provideniya is getting retreived
# The data of city with number: 198 and name: provideniya is successfully retreived
# The data of city with number: 199 and name: chernyshevskiy is getting retreived
# The data of city with number: 199 and name: chernyshevskiy is successfully retreived
# The data of city with number: 200 and name: svetlaya is getting retreived
# The data of city with number: 200 and name: svetlaya is successfully retreived
# The data of city with number: 201 and name: tabou is getting retreived
# The data of city with number: 201 and name: tabou is successfully retreived
# The data of city with number: 202 and name: katsuura is getting retreived
# The data of city with number: 202 and name: katsuura is successfully retreived
# The data of city with number: 203 and name: salalah is getting retreived
# The data of city with number: 203 and name: salalah is successfully retreived
# The data of city with number: 204 and name: vilyuysk is getting retreived
# The data of city with number: 204 and name: vilyuysk is successfully retreived
# The data of city with number: 205 and name: tessalit is getting retreived
# The data of city with number: 205 and name: tessalit is successfully retreived
# The data of city with number: 206 and name: svetlogorsk is getting retreived
# The data of city with number: 206 and name: svetlogorsk is successfully retreived
# The data of city with number: 207 and name: guerrero negro is getting retreived
# The data of city with number: 207 and name: guerrero negro is successfully retreived
# The data of city with number: 208 and name: yerofey pavlovich is getting retreived
# The data of city with number: 208 and name: yerofey pavlovich is successfully retreived
# The data of city with number: 209 and name: dudinka is getting retreived
# The data of city with number: 209 and name: dudinka is successfully retreived
# The data of city with number: 210 and name: fort morgan is getting retreived
# The data of city with number: 210 and name: fort morgan is successfully retreived
# The data of city with number: 211 and name: kardla is getting retreived
# The data of city with number: 211 and name: kardla is successfully retreived
# The data of city with number: 212 and name: naze is getting retreived
# The data of city with number: 212 and name: naze is successfully retreived
# The data of city with number: 213 and name: presidencia roque saenz pena is getting retreived
# The data of city with number: 213 and name: presidencia roque saenz pena is successfully retreived
# The data of city with number: 214 and name: narsaq is getting retreived
# The data of city with number: 214 and name: narsaq is successfully retreived
# The data of city with number: 215 and name: porto novo is getting retreived
# The data of city with number: 215 and name: porto novo is successfully retreived
# The data of city with number: 216 and name: vao is getting retreived
# The data of city with number: 216 and name: vao is successfully retreived
# The data of city with number: 217 and name: barrow is getting retreived
# The data of city with number: 217 and name: barrow is successfully retreived
# The data of city with number: 218 and name: nanortalik is getting retreived
# The data of city with number: 218 and name: nanortalik is successfully retreived
# The data of city with number: 219 and name: merauke is getting retreived
# The data of city with number: 219 and name: merauke is successfully retreived
# The data of city with number: 220 and name: mulchen is getting retreived
# The data of city with number: 220 and name: mulchen is successfully retreived
# The data of city with number: 221 and name: kloulklubed is getting retreived
# The data of city with number: 221 and name: kloulklubed is successfully retreived
# The data of city with number: 222 and name: boueni is getting retreived
# The data of city with number: 222 and name: boueni is successfully retreived
# The data of city with number: 223 and name: san policarpo is getting retreived
# The data of city with number: 223 and name: san policarpo is successfully retreived
# The data of city with number: 224 and name: ndele is getting retreived
# The data of city with number: 224 and name: ndele is successfully retreived
# The data of city with number: 225 and name: khasan is getting retreived
# The data of city with number: 225 and name: khasan is successfully retreived
# The data of city with number: 226 and name: pemba is getting retreived
# The data of city with number: 226 and name: pemba is successfully retreived
# The data of city with number: 227 and name: chicama is getting retreived
# The data of city with number: 227 and name: chicama is successfully retreived
# The data of city with number: 228 and name: mandan is getting retreived
# The data of city with number: 228 and name: mandan is successfully retreived
# The data of city with number: 229 and name: east london is getting retreived
# The data of city with number: 229 and name: east london is successfully retreived
# The data of city with number: 230 and name: frederico westphalen is getting retreived
# The data of city with number: 230 and name: frederico westphalen is successfully retreived
# The data of city with number: 231 and name: halalo is getting retreived
# The data of city with number: 231 and name: halalo is not found!
#  Removing from the list
# The data of city with number: 232 and name: lebu is getting retreived
# The data of city with number: 232 and name: lebu is successfully retreived
# The data of city with number: 233 and name: key largo is getting retreived
# The data of city with number: 233 and name: key largo is successfully retreived
# The data of city with number: 234 and name: coulihaut is getting retreived
# The data of city with number: 234 and name: coulihaut is not found!
#  Removing from the list
# The data of city with number: 235 and name: laguna is getting retreived
# The data of city with number: 235 and name: laguna is successfully retreived
# The data of city with number: 236 and name: tumannyy is getting retreived
# The data of city with number: 236 and name: tumannyy is not found!
#  Removing from the list
# The data of city with number: 237 and name: marcona is getting retreived
# The data of city with number: 237 and name: marcona is not found!
#  Removing from the list
# The data of city with number: 238 and name: cayenne is getting retreived
# The data of city with number: 238 and name: cayenne is successfully retreived
# The data of city with number: 239 and name: shingu is getting retreived
# The data of city with number: 239 and name: shingu is successfully retreived
# The data of city with number: 240 and name: barentsburg is getting retreived
# The data of city with number: 240 and name: barentsburg is not found!
#  Removing from the list
# The data of city with number: 241 and name: onalaska is getting retreived
# The data of city with number: 241 and name: onalaska is successfully retreived
# The data of city with number: 242 and name: leh is getting retreived
# The data of city with number: 242 and name: leh is successfully retreived
# The data of city with number: 243 and name: geraldton is getting retreived
# The data of city with number: 243 and name: geraldton is successfully retreived
# The data of city with number: 244 and name: pisco is getting retreived
# The data of city with number: 244 and name: pisco is successfully retreived
# The data of city with number: 245 and name: san patricio is getting retreived
# The data of city with number: 245 and name: san patricio is successfully retreived
# The data of city with number: 246 and name: havelock is getting retreived
# The data of city with number: 246 and name: havelock is successfully retreived
# The data of city with number: 247 and name: melilla is getting retreived
# The data of city with number: 247 and name: melilla is successfully retreived
# The data of city with number: 248 and name: avera is getting retreived
# The data of city with number: 248 and name: avera is successfully retreived
# The data of city with number: 249 and name: rudnogorsk is getting retreived
# The data of city with number: 249 and name: rudnogorsk is successfully retreived
# The data of city with number: 250 and name: tautira is getting retreived
# The data of city with number: 250 and name: tautira is successfully retreived
# The data of city with number: 251 and name: dalvik is getting retreived
# The data of city with number: 251 and name: dalvik is successfully retreived
# The data of city with number: 252 and name: santa cruz de tenerife is getting retreived
# The data of city with number: 252 and name: santa cruz de tenerife is successfully retreived
# The data of city with number: 253 and name: hit is getting retreived
# The data of city with number: 253 and name: hit is successfully retreived
# The data of city with number: 254 and name: vila franca do campo is getting retreived
# The data of city with number: 254 and name: vila franca do campo is successfully retreived
# The data of city with number: 255 and name: namatanai is getting retreived
# The data of city with number: 255 and name: namatanai is successfully retreived
# The data of city with number: 256 and name: ilulissat is getting retreived
# The data of city with number: 256 and name: ilulissat is successfully retreived
# The data of city with number: 257 and name: ternate is getting retreived
# The data of city with number: 257 and name: ternate is successfully retreived
# The data of city with number: 258 and name: moiyabana is getting retreived
# The data of city with number: 258 and name: moiyabana is not found!
#  Removing from the list
# The data of city with number: 259 and name: chemax is getting retreived
# The data of city with number: 259 and name: chemax is successfully retreived
# The data of city with number: 260 and name: kiunga is getting retreived
# The data of city with number: 260 and name: kiunga is successfully retreived
# The data of city with number: 261 and name: mahebourg is getting retreived
# The data of city with number: 261 and name: mahebourg is successfully retreived
# The data of city with number: 262 and name: ixtapa is getting retreived
# The data of city with number: 262 and name: ixtapa is successfully retreived
# The data of city with number: 263 and name: severo-kurilsk is getting retreived
# The data of city with number: 263 and name: severo-kurilsk is successfully retreived
# The data of city with number: 264 and name: hasaki is getting retreived
# The data of city with number: 264 and name: hasaki is successfully retreived
# The data of city with number: 265 and name: santa maria is getting retreived
# The data of city with number: 265 and name: santa maria is successfully retreived
# The data of city with number: 266 and name: muana is getting retreived
# The data of city with number: 266 and name: muana is successfully retreived
# The data of city with number: 267 and name: santa catarina de tepehuanes is getting retreived
# The data of city with number: 267 and name: santa catarina de tepehuanes is successfully retreived
# The data of city with number: 268 and name: bathsheba is getting retreived
# The data of city with number: 268 and name: bathsheba is successfully retreived
# The data of city with number: 269 and name: ituni is getting retreived
# The data of city with number: 269 and name: ituni is not found!
#  Removing from the list
# The data of city with number: 270 and name: meulaboh is getting retreived
# The data of city with number: 270 and name: meulaboh is successfully retreived
# The data of city with number: 271 and name: ust-nera is getting retreived
# The data of city with number: 271 and name: ust-nera is successfully retreived
# The data of city with number: 272 and name: ustka is getting retreived
# The data of city with number: 272 and name: ustka is successfully retreived
# The data of city with number: 273 and name: verkhoyansk is getting retreived
# The data of city with number: 273 and name: verkhoyansk is successfully retreived
# The data of city with number: 274 and name: karratha is getting retreived
# The data of city with number: 274 and name: karratha is successfully retreived
# The data of city with number: 275 and name: calama is getting retreived
# The data of city with number: 275 and name: calama is successfully retreived
# The data of city with number: 276 and name: touros is getting retreived
# The data of city with number: 276 and name: touros is successfully retreived
# The data of city with number: 277 and name: nakamura is getting retreived
# The data of city with number: 277 and name: nakamura is successfully retreived
# The data of city with number: 278 and name: bambous virieux is getting retreived
# The data of city with number: 278 and name: bambous virieux is successfully retreived
# The data of city with number: 279 and name: floro is getting retreived
# The data of city with number: 279 and name: floro is successfully retreived
# The data of city with number: 280 and name: longyearbyen is getting retreived
# The data of city with number: 280 and name: longyearbyen is successfully retreived
# The data of city with number: 281 and name: rawson is getting retreived
# The data of city with number: 281 and name: rawson is successfully retreived
# The data of city with number: 282 and name: carovigno is getting retreived
# The data of city with number: 282 and name: carovigno is successfully retreived
# The data of city with number: 283 and name: taoudenni is getting retreived
# The data of city with number: 283 and name: taoudenni is successfully retreived
# The data of city with number: 284 and name: litovko is getting retreived
# The data of city with number: 284 and name: litovko is successfully retreived
# The data of city with number: 285 and name: mount isa is getting retreived
# The data of city with number: 285 and name: mount isa is successfully retreived
# The data of city with number: 286 and name: muros is getting retreived
# The data of city with number: 286 and name: muros is successfully retreived
# The data of city with number: 287 and name: codrington is getting retreived
# The data of city with number: 287 and name: codrington is successfully retreived
# The data of city with number: 288 and name: uyuni is getting retreived
# The data of city with number: 288 and name: uyuni is successfully retreived
# The data of city with number: 289 and name: carman is getting retreived
# The data of city with number: 289 and name: carman is successfully retreived
# The data of city with number: 290 and name: torbay is getting retreived
# The data of city with number: 290 and name: torbay is successfully retreived
# The data of city with number: 291 and name: ust-kuyga is getting retreived
# The data of city with number: 291 and name: ust-kuyga is successfully retreived
# The data of city with number: 292 and name: marathon is getting retreived
# The data of city with number: 292 and name: marathon is successfully retreived
# The data of city with number: 293 and name: matara is getting retreived
# The data of city with number: 293 and name: matara is successfully retreived
# The data of city with number: 294 and name: motygino is getting retreived
# The data of city with number: 294 and name: motygino is successfully retreived
# The data of city with number: 295 and name: puerto ayora is getting retreived
# The data of city with number: 295 and name: puerto ayora is successfully retreived
# The data of city with number: 296 and name: kirakira is getting retreived
# The data of city with number: 296 and name: kirakira is successfully retreived
# The data of city with number: 297 and name: burnie is getting retreived
# The data of city with number: 297 and name: burnie is successfully retreived
# The data of city with number: 298 and name: abha is getting retreived
# The data of city with number: 298 and name: abha is successfully retreived
# The data of city with number: 299 and name: lorengau is getting retreived
# The data of city with number: 299 and name: lorengau is successfully retreived
# The data of city with number: 300 and name: jalu is getting retreived
# The data of city with number: 300 and name: jalu is successfully retreived
# The data of city with number: 301 and name: vestmannaeyjar is getting retreived
# The data of city with number: 301 and name: vestmannaeyjar is successfully retreived
# The data of city with number: 302 and name: gamba is getting retreived
# The data of city with number: 302 and name: gamba is successfully retreived
# The data of city with number: 303 and name: amderma is getting retreived
# The data of city with number: 303 and name: amderma is not found!
#  Removing from the list
# The data of city with number: 304 and name: kutum is getting retreived
# The data of city with number: 304 and name: kutum is successfully retreived
# The data of city with number: 305 and name: haifa is getting retreived
# The data of city with number: 305 and name: haifa is successfully retreived
# The data of city with number: 306 and name: konakovo is getting retreived
# The data of city with number: 306 and name: konakovo is successfully retreived
# The data of city with number: 307 and name: nikolskoye is getting retreived
# The data of city with number: 307 and name: nikolskoye is successfully retreived
# The data of city with number: 308 and name: saint-leu is getting retreived
# The data of city with number: 308 and name: saint-leu is successfully retreived
# The data of city with number: 309 and name: souillac is getting retreived
# The data of city with number: 309 and name: souillac is successfully retreived
# The data of city with number: 310 and name: viedma is getting retreived
# The data of city with number: 310 and name: viedma is successfully retreived
# The data of city with number: 311 and name: padang is getting retreived
# ...
# The data of city with number: 516 and name: shache is getting retreived
# The data of city with number: 516 and name: shache is successfully retreived
# The data of city with number: 517 and name: aswan is getting retreived
# The data of city with number: 517 and name: aswan is successfully retreived
# The data of city with number: 518 and name: gmund is getting retreived
# The data of city with number: 518 and name: gmund is successfully retreived
# The data of city with number: 519 and name: saint-louis is getting retreived
# The data of city with number: 519 and name: saint-louis is successfully retreived
# The data of city with number: 520 and name: wahran is getting retreived
# The data of city with number: 520 and name: wahran is not found!
#  Removing from the list
# The data of city with number: 521 and name: kamaishi is getting retreived
# The data of city with number: 521 and name: kamaishi is successfully retreived
# The data of city with number: 522 and name: sao miguel do araguaia is getting retreived
# The data of city with number: 522 and name: sao miguel do araguaia is successfully retreived
# The data of city with number: 523 and name: korla is getting retreived
# The data of city with number: 523 and name: korla is successfully retreived
# The data of city with number: 524 and name: vondrozo is getting retreived
# The data of city with number: 524 and name: vondrozo is successfully retreived
# The data of city with number: 525 and name: saint-denis is getting retreived
# The data of city with number: 525 and name: saint-denis is successfully retreived
# The data of city with number: 526 and name: puerto cortes is getting retreived
# The data of city with number: 526 and name: puerto cortes is not found!
#  Removing from the list
# The data of city with number: 527 and name: kapoeta is getting retreived
# The data of city with number: 527 and name: kapoeta is successfully retreived
# The data of city with number: 528 and name: kulhudhuffushi is getting retreived
# The data of city with number: 528 and name: kulhudhuffushi is successfully retreived
# The data of city with number: 529 and name: gat is getting retreived
# The data of city with number: 529 and name: gat is successfully retreived
# The data of city with number: 530 and name: axim is getting retreived
# The data of city with number: 530 and name: axim is successfully retreived
# The data of city with number: 531 and name: aykhal is getting retreived
# The data of city with number: 531 and name: aykhal is successfully retreived
# The data of city with number: 532 and name: kathu is getting retreived
# The data of city with number: 532 and name: kathu is successfully retreived
# The data of city with number: 533 and name: matamoros is getting retreived
# The data of city with number: 533 and name: matamoros is successfully retreived
# The data of city with number: 534 and name: dakar is getting retreived
# The data of city with number: 534 and name: dakar is successfully retreived
# The data of city with number: 535 and name: ruatoria is getting retreived
# The data of city with number: 535 and name: ruatoria is not found!
#  Removing from the list
# The data of city with number: 536 and name: asfi is getting retreived
# The data of city with number: 536 and name: asfi is successfully retreived
# The data of city with number: 537 and name: barabai is getting retreived
# The data of city with number: 537 and name: barabai is successfully retreived
# The data of city with number: 538 and name: kristianstad is getting retreived
# The data of city with number: 538 and name: kristianstad is successfully retreived
# The data of city with number: 539 and name: marawi is getting retreived
# The data of city with number: 539 and name: marawi is successfully retreived
# The data of city with number: 540 and name: luanda is getting retreived
# The data of city with number: 540 and name: luanda is successfully retreived
# The data of city with number: 541 and name: alofi is getting retreived
# The data of city with number: 541 and name: alofi is successfully retreived
# The data of city with number: 542 and name: dores do indaia is getting retreived
# The data of city with number: 542 and name: dores do indaia is successfully retreived
# The data of city with number: 543 and name: villazon is getting retreived
# The data of city with number: 543 and name: villazon is successfully retreived
# The data of city with number: 544 and name: horodok is getting retreived
# The data of city with number: 544 and name: horodok is successfully retreived
# The data of city with number: 545 and name: solnechnyy is getting retreived
# The data of city with number: 545 and name: solnechnyy is successfully retreived
# The data of city with number: 546 and name: sawtell is getting retreived
# The data of city with number: 546 and name: sawtell is successfully retreived
# The data of city with number: 547 and name: ous is getting retreived
# The data of city with number: 547 and name: ous is successfully retreived
# The data of city with number: 548 and name: bocaiuva is getting retreived
# The data of city with number: 548 and name: bocaiuva is successfully retreived
# The data of city with number: 549 and name: totma is getting retreived
# The data of city with number: 549 and name: totma is successfully retreived
# The data of city with number: 550 and name: shu is getting retreived
# The data of city with number: 550 and name: shu is successfully retreived
# The data of city with number: 551 and name: dankov is getting retreived
# The data of city with number: 551 and name: dankov is successfully retreived
# The data of city with number: 552 and name: faya is getting retreived
# The data of city with number: 552 and name: faya is successfully retreived
# The data of city with number: 553 and name: tezu is getting retreived
# The data of city with number: 553 and name: tezu is successfully retreived
# The data of city with number: 554 and name: buin is getting retreived
# The data of city with number: 554 and name: buin is successfully retreived
# The data of city with number: 555 and name: huntsville is getting retreived
# The data of city with number: 555 and name: huntsville is successfully retreived
# The data of city with number: 556 and name: bilma is getting retreived
# The data of city with number: 556 and name: bilma is successfully retreived
# The data of city with number: 557 and name: gaya is getting retreived
# The data of city with number: 557 and name: gaya is successfully retreived
# The data of city with number: 558 and name: miranda is getting retreived
# The data of city with number: 558 and name: miranda is successfully retreived
# The data of city with number: 559 and name: sao tome is getting retreived
# The data of city with number: 559 and name: sao tome is successfully retreived
# The data of city with number: 560 and name: uwayl is getting retreived
# The data of city with number: 560 and name: uwayl is not found!
#  Removing from the list
# The data of city with number: 561 and name: phrai bung is getting retreived
# The data of city with number: 561 and name: phrai bung is not found!
#  Removing from the list
# The data of city with number: 562 and name: esmeraldas is getting retreived
# The data of city with number: 562 and name: esmeraldas is successfully retreived
# The data of city with number: 563 and name: leshukonskoye is getting retreived
# The data of city with number: 563 and name: leshukonskoye is successfully retreived
# The data of city with number: 564 and name: damavand is getting retreived
# The data of city with number: 564 and name: damavand is successfully retreived
# The data of city with number: 565 and name: bud is getting retreived
# The data of city with number: 565 and name: bud is successfully retreived
# The data of city with number: 566 and name: riohacha is getting retreived
# The data of city with number: 566 and name: riohacha is successfully retreived
# The data of city with number: 567 and name: biskamzha is getting retreived
# The data of city with number: 567 and name: biskamzha is successfully retreived
# The data of city with number: 568 and name: greenville is getting retreived
# The data of city with number: 568 and name: greenville is successfully retreived
# The data of city with number: 569 and name: katangli is getting retreived
# The data of city with number: 569 and name: katangli is successfully retreived
# The data of city with number: 570 and name: whyalla is getting retreived
# The data of city with number: 570 and name: whyalla is successfully retreived
# The data of city with number: 571 and name: mussomeli is getting retreived
# The data of city with number: 571 and name: mussomeli is successfully retreived
# The data of city with number: 572 and name: boa vista is getting retreived
# The data of city with number: 572 and name: boa vista is successfully retreived
# The data of city with number: 573 and name: noumea is getting retreived
# The data of city with number: 573 and name: noumea is successfully retreived
# The data of city with number: 574 and name: namibe is getting retreived
# The data of city with number: 574 and name: namibe is successfully retreived
# The data of city with number: 575 and name: riorges is getting retreived
# The data of city with number: 575 and name: riorges is successfully retreived
# The data of city with number: 576 and name: kabinda is getting retreived
# The data of city with number: 576 and name: kabinda is successfully retreived
# The data of city with number: 577 and name: coihaique is getting retreived
# The data of city with number: 577 and name: coihaique is successfully retreived
# The data of city with number: 578 and name: bouar is getting retreived
# The data of city with number: 578 and name: bouar is successfully retreived
# The data of city with number: 579 and name: risor is getting retreived
# The data of city with number: 579 and name: risor is successfully retreived
# The data of city with number: 580 and name: kuche is getting retreived
# The data of city with number: 580 and name: kuche is not found!
#  Removing from the list
# The data of city with number: 581 and name: vermillion is getting retreived
# The data of city with number: 581 and name: vermillion is successfully retreived
# The data of city with number: 582 and name: salistea de sus is getting retreived
# The data of city with number: 582 and name: salistea de sus is successfully retreived
# The data of city with number: 583 and name: inuvik is getting retreived
# The data of city with number: 583 and name: inuvik is successfully retreived
# The data of city with number: 584 and name: nagato is getting retreived
# The data of city with number: 584 and name: nagato is successfully retreived
# The data of city with number: 585 and name: kingston upon hull is getting retreived
# The data of city with number: 585 and name: kingston upon hull is successfully retreived
# The data of city with number: 586 and name: yellandu is getting retreived
# The data of city with number: 586 and name: yellandu is successfully retreived
# The data of city with number: 587 and name: beyneu is getting retreived
# The data of city with number: 587 and name: beyneu is successfully retreived
# The data of city with number: 588 and name: chupaca is getting retreived
# The data of city with number: 588 and name: chupaca is successfully retreived
# The data of city with number: 589 and name: fortuna is getting retreived
# The data of city with number: 589 and name: fortuna is successfully retreived
# The data of city with number: 590 and name: ierapetra is getting retreived
# The data of city with number: 590 and name: ierapetra is successfully retreived
# The data of city with number: 591 and name: eyl is getting retreived
# The data of city with number: 591 and name: eyl is successfully retreived
# The data of city with number: 592 and name: stryn is getting retreived
# The data of city with number: 592 and name: stryn is successfully retreived
# The data of city with number: 593 and name: ayia marina is getting retreived
# The data of city with number: 593 and name: ayia marina is successfully retreived
# The data of city with number: 594 and name: ponta delgada is getting retreived
# The data of city with number: 594 and name: ponta delgada is successfully retreived
# The data of city with number: 595 and name: berlevag is getting retreived
# The data of city with number: 595 and name: berlevag is successfully retreived
# The data of city with number: 596 and name: saraland is getting retreived
# The data of city with number: 596 and name: saraland is successfully retreived
# The data of city with number: 597 and name: oxbow is getting retreived
# The data of city with number: 597 and name: oxbow is successfully retreived
# The data of city with number: 598 and name: dashitou is getting retreived
# The data of city with number: 598 and name: dashitou is successfully retreived
# The data of city with number: 599 and name: makakilo city is getting retreived
# The data of city with number: 599 and name: makakilo city is successfully retreived
# The data of city with number: 600 and name: wilkie is getting retreived
# The data of city with number: 600 and name: wilkie is successfully retreived
# The data of city with number: 601 and name: dunedin is getting retreived
# The data of city with number: 601 and name: dunedin is successfully retreived
# The data of city with number: 602 and name: salmas is getting retreived
# The data of city with number: 602 and name: salmas is successfully retreived
# The data of city with number: 603 and name: oberstdorf is getting retreived
# The data of city with number: 603 and name: oberstdorf is successfully retreived
# The data of city with number: 604 and name: vuktyl is getting retreived
# The data of city with number: 604 and name: vuktyl is successfully retreived
# The data of city with number: 605 and name: diamantina is getting retreived
# The data of city with number: 605 and name: diamantina is successfully retreived
# The data of city with number: 606 and name: usinsk is getting retreived
# The data of city with number: 606 and name: usinsk is successfully retreived
# The data of city with number: 607 and name: fayaoue is getting retreived
# The data of city with number: 607 and name: fayaoue is successfully retreived
# The data of city with number: 608 and name: do gonbadan is getting retreived
# The data of city with number: 608 and name: do gonbadan is successfully retreived
# The data of city with number: 609 and name: killybegs is getting retreived
# The data of city with number: 609 and name: killybegs is successfully retreived
# The data of city with number: 610 and name: urdzhar is getting retreived
# The data of city with number: 610 and name: urdzhar is not found!
#  Removing from the list
# The data of city with number: 611 and name: iqaluit is getting retreived
# The data of city with number: 611 and name: iqaluit is successfully retreived
# The data of city with number: 612 and name: caxito is getting retreived
# The data of city with number: 612 and name: caxito is successfully retreived
# The data of city with number: 613 and name: comodoro rivadavia is getting retreived
# The data of city with number: 613 and name: comodoro rivadavia is successfully retreived
# The data of city with number: 614 and name: amapa is getting retreived
# The data of city with number: 614 and name: amapa is successfully retreived
# The data of city with number: 615 and name: saint-joseph is getting retreived
# The data of city with number: 615 and name: saint-joseph is successfully retreived
# The data of city with number: 616 and name: udachnyy is getting retreived
# The data of city with number: 616 and name: udachnyy is successfully retreived
# The data of city with number: 617 and name: hervey bay is getting retreived
# The data of city with number: 617 and name: hervey bay is successfully retreived
# The data of city with number: 618 and name: nantucket is getting retreived
# The data of city with number: 618 and name: nantucket is successfully retreived
#
# The weather data of 618 cities has been requested!
#
# The weather data for 50 cities are not found!
#
# The weather data of 568 cities has been successfully retrieved

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {"City":city_name,"Cloudiness":cloudiness,"Country":country,"Date":date1,
              "Humidity":humidity,"Latitude":latitude,"Longitude":longitude,
              "Max Temperature":max_temp,"Wind Speed":wind_Speed}

weather_data = pd.DataFrame(weather_dict)
weather_data.index.rename('City ID', inplace=True)
weather_data.to_csv(output_data_file)
weather_data.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity  Latitude  \
# City ID
# 0          punta arenas          20      CL  1615395030        46  -53.1500
# 1        saint-philippe           0      RE  1615395036        74  -21.3585
# 2              kandrian          99      PG  1615395039        85   -6.2167
# 3              cidreira           0      BR  1615395041        70  -30.1811
# 4              mosquera          40      CO  1615395043        52    4.7059
#
#          Longitude  Max Temperature  Wind Speed
# City ID
# 0         -70.9167            51.80       31.07
# 1          55.7679            80.60       16.11
# 2         149.5500            77.31        3.60
# 3         -50.2056            75.00        9.35
# 4         -74.2302            66.20        2.30

# %%
number_of_cities = weather_data['City'].nunique()
print(f'The weather information of {number_of_cities} cities are in the dataframe')
# Out:
# The weather information of 568 cities are in the dataframe

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data_humid = weather_data.loc[weather_data['Humidity'] > 100,:]
weather_data_humid['City'].count()
# Out:
# 0

# %% [markdown]
# **Report:**
# `weather_data` dataframe does not have any city with humidity over 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp = weather_data.plot(kind = 'scatter',x = 'Latitude', y= 'Max Temperature',
                  marker = 'o', c = 'red',
                  title = 'Temperature (F) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')',
                  grid = True,edgecolors='black')

plt.ylabel("Maximum Temperature (f)")
lat_temp.set_axisbelow(True)
plt.savefig("Output Data/Images/lat_vs_temp.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Analysis:**
# > - This scatter plot shows the relation between `Latitude` and `Maximum Temperature` for the cities in the list.<br>
# > - With the increase in latitude(that is., above equator), the maximum temperature in the cities are getting reduced. We can see a strong relationship between Latitude and maximum Temperature in the region.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humid = weather_data.plot(kind = 'scatter',x = 'Latitude', y= 'Humidity', c= 'red',
                  title = 'Humidity (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')',
                  grid = True,edgecolors='black')

plt.ylabel("Humidity (%)")
lat_humid.set_axisbelow(True)
plt.savefig("Output Data/Images/lat_vs_humidity.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Analysis:**
# > - This scatter plot shows the relation between `Latitude` and `Humidity` for the cities in the list.<br>
# > - We could not find a specific pattern in the weather data with respect to humidity. The data is spread all over the x-axis. Latitude and humidity does not have strong relations between them.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud = weather_data.plot(kind = 'scatter',x = 'Latitude', y= 'Cloudiness', c= 'red',
                  title = 'Cloudiness (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')',
                  grid = True,edgecolors='black')

lat_cloud.set_ylabel("Cloudiness (%)")
lat_cloud.set_axisbelow(True)
plt.savefig("Output Data/Images/lat_vs_cloudiness.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Analysis:**
# > - This scatter plot shows the relation between `Latitude` and `Cloudiness` for the cities in the list.<br>
# > - We could not find a specific pattern in the weather data with respect to Cloudiness. The data is spread all over the x-axis. Latitude and cloudiness does not have strong relations between them.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind_speed = weather_data.plot(kind = 'scatter',x = 'Latitude', y= 'Wind Speed',c = 'red',
                  title = 'Wind Speed (mph) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')',
                  grid = True,edgecolors='black')

lat_wind_speed.set_ylabel("Wind Speed (mph)")
lat_wind_speed.set_axisbelow(True)
plt.savefig("Output Data/Images/lat_vs_wind_speed.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Analysis:**
# > - This scatter plot shows the relation between `Latitude` and `Wind Speed` for the cities in the list.<br>
# > - We could not find a specific pattern in the weather data with respect to Wind Speed. The data is spread all over the x-axis. Latitude and Wind Speed does not have strong relations between them.

# %% [markdown]
# ## Linear Regression

# %%
#Weather data for cities in northern hemisphere
weather_north_hemis = weather_data.loc[weather_data['Latitude'] >= 0]
weather_north_hemis_df = weather_north_hemis.reset_index(drop = True)

#Weather data for cities in southern hemisphere
weather_south_hemis = weather_data.loc[weather_data['Latitude'] < 0]
weather_south_hemis_df = weather_south_hemis.reset_index(drop = True)

north_hemis_x = weather_north_hemis_df['Latitude']
south_hemis_x = weather_south_hemis_df['Latitude']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_temp_y = weather_north_hemis_df['Max Temperature']

slope_nt,intercept_nt,rvalue_nt,pvalue_nt,stderr_nt = linregress(north_hemis_x,north_temp_y)
regress_value_nt = north_hemis_x * slope_nt + intercept_nt
line_temp_eq = "y = " + str(round(slope_nt,2)) + "x + " + str(round(intercept_nt,2))

fig,ax1 = plt.subplots()
ax1.scatter(north_hemis_x,north_temp_y,label = "Datapoint",edgecolors = 'black')
ax1.plot(north_hemis_x,regress_value_nt,"--",color='r',label = "Linear regression:\n"+line_temp_eq)


ax1.set_title('Northern Hemisphere: Temperature (F) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax1.set_xlabel('Latitude')
ax1.set_ylabel('Maximum Temperature (F)')
plt.legend(loc = "best")
ax1.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/north_hemis_lat_vs_temp.png")
plt.show()

corr_temp_n = pearsonr(north_hemis_x,north_temp_y)
print(f'The correlation coefficient between temperature and latitude in northern hemisphere is: {corr_temp_n}')
# Out:
# <img src="data:image/png;base64,..." width="640">
# The correlation coefficient between temperature and latitude in northern hemisphere is: (-0.9009230324782943, 4.296831213188401e-147)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_temp_y = weather_south_hemis_df['Max Temperature']

slope_st,intercept_st,rvalue_st,pvalue_st,stderr_st = linregress(south_hemis_x,south_temp_y)
regress_value_st = south_hemis_x * slope_st + intercept_st
line_temp2_eq = "y = " + str(round(slope_st,2)) + "x + " + str(round(intercept_st,2))

fig,ax2 = plt.subplots(1,1,figsize = (8,5))
ax2.scatter(south_hemis_x,south_temp_y,label = "Datapoint",edgecolors = 'black')
ax2.plot(south_hemis_x,regress_value_st,'r--',color='r',label = "Linear regression:\n" + line_temp2_eq)

ax2.set_title('Southern Hemisphere: Temperature (F) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax2.set_xlabel('Latitude')
ax2.set_ylabel('Maximum Temperature (F)')
ax2.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax2.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/south_hemis_lat_vs_temp.png")
plt.show()
plt.tight_layout()

corr_temp = pearsonr(south_hemis_x,south_temp_y)
print(f'The correlation coefficient between temperature and latitude in southern hemisphere is: {corr_temp}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between temperature and latitude in southern hemisphere is: (0.5880059922268366, 8.139256864521336e-17)

# %% [markdown]
# **Analysis:**
# > - From the plots `Northern Hemisphere - Temperature (F) vs. Latitude` & `Southern Hemisphere - Temperature (F) vs. Latitude`, we can find that the maximum temperature felt is increasing as we move towards the equator.<br>
# > - In the northern hemisphere, temperature and latitude has a strong negative correlation.<br>
# > - In the souther hemisphere, temperature and latitude has a moderate positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_humid_y = weather_north_hemis_df['Humidity']

slope_nh,intercept_nh,rvalue_nh,pvalue_nh,stderr_nh = linregress(north_hemis_x,north_humid_y)
regress_value_nh = north_hemis_x * slope_nh + intercept_nh
line_humid1_eq = "y = " + str(round(slope_nh,2)) + "x + " + str(round(intercept_nh,2))

fig,ax3 = plt.subplots(1,1,figsize = (8,5))
ax3.scatter(north_hemis_x,north_humid_y,label = "Datapoint",edgecolors = 'black')
ax3.plot(north_hemis_x,regress_value_nh,"--",color='r',label = "Linear regression:\n" + line_humid1_eq)

ax3.set_title('Northern Hemisphere: Humidity (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax3.set_xlabel('Latitude')
ax3.set_ylabel('Humidity (%)')
ax3.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.grid(color='gray', linestyle='dashed')
ax3.set_axisbelow(True)

plt.savefig("Output Data/Images/north_hemis_lat_vs_humid.png")
plt.show()
plt.tight_layout()

corr_humid_n = pearsonr(north_hemis_x,north_humid_y)
print(f'The correlation coefficient between humidity and latitude is: {corr_humid_n}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between humidity and latitude is: (0.36857679100235324, 2.2152986514391724e-14)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_humid_y = weather_south_hemis_df['Humidity']

slope_sh,intercept_sh,rvalue_sh,pvalue_sh,stderr_sh = linregress(south_hemis_x,south_humid_y)
regress_value_sh = south_hemis_x * slope_sh + intercept_sh
line_humid2_eq = "y = " + str(round(slope_sh,2)) + "x + " + str(round(intercept_sh,2))

fig,ax4 = plt.subplots(1,1,figsize = (8,5))
ax4.scatter(south_hemis_x,south_humid_y,label = "Datapoint",edgecolors = 'black')
ax4.plot(south_hemis_x,regress_value_sh,"--",color='r',label = "Linear regression:\n" + line_humid2_eq)

ax4.set_title('Southern Hemisphere: Humidity (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax4.set_xlabel('Latitude')
ax4.set_ylabel('Humidity (%)')
ax4.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax4.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/south_hemis_lat_vs_humid.png")
plt.show()
plt.tight_layout()

corr_humid_s = pearsonr(south_hemis_x,south_temp_y)
print(f'The correlation coefficient between humidity and latitude is: {corr_humid_s}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between humidity and latitude is: (0.5880059922268366, 8.139256864521336e-17)

# %% [markdown]
# **Analysis:**
# > - From the plots `Northern Hemisphere - Humidity vs. Latitude` & `Southern Hemisphere - Humidity vs. Latitude`, we can find that there is not much strong relation between data.<br>
# > - In the northern hemisphere, humidity and latitude has a week positive correlation.<br>
# > - In the souther hemisphere, humidity and latitude has a moderate positive correlation.<br>
# > - It concludes that humidity and latitude are not correlated.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_cloud_y = weather_north_hemis_df['Cloudiness']

slope_nc,intercept_nc,rvalue_nc,pvalue_nc,stderr_nc = linregress(north_hemis_x,north_cloud_y)
regress_value_nc = north_hemis_x * slope_nc + intercept_nc
line_cloud1_eq = "y = " + str(round(slope_nc,2)) + "x + " + str(round(intercept_nc,2))

fig,ax5 = plt.subplots(1,1,figsize = (8,5))
ax5.scatter(north_hemis_x,north_cloud_y,label = "Datapoint",edgecolors = 'black')
ax5.plot(north_hemis_x,regress_value_nc,"--",color='r',label = "Linear regression:\n" + line_cloud1_eq)

ax5.set_title('Northern Hemisphere: Cloudiness (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax5.set_xlabel('Latitude')
ax5.set_ylabel('Cloudiness (%)')
ax5.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax5.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/north_hemis_lat_vs_cloud.png")
plt.show()
plt.tight_layout()

corr_cloud_n = pearsonr(north_hemis_x,north_cloud_y)
print(f'The correlation coefficient between cloudiness and latitude is: {corr_cloud_n}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between cloudiness and latitude is: (0.1166890214732354, 0.01926709640667481)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_cloud_y = weather_south_hemis_df['Cloudiness']

slope_sc,intercept_sc,rvalue_sc,pvalue_sc,stderr_sc = linregress(south_hemis_x,south_cloud_y)
regress_value_sc = south_hemis_x * slope_sc + intercept_sc
line_cloud2_eq = "y = " + str(round(slope_sc,2)) + "x + " + str(round(intercept_sc,2))

fig,ax6 = plt.subplots(1,1,figsize = (8,5))
ax6.scatter(south_hemis_x,south_cloud_y,label = "Datapoint",edgecolors = 'black')
ax6.plot(south_hemis_x,regress_value_sc,"--",color='r',label = "Linear regression:\n" + line_cloud2_eq)

ax6.set_title('Southern Hemisphere: Cloudiness (%) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax6.set_xlabel('Latitude')
ax6.set_ylabel('Cloudiness (%)')
ax6.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax6.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/south_hemis_lat_vs_cloud.png")
plt.show()
plt.tight_layout()

corr_cloud_s = pearsonr(south_hemis_x,south_cloud_y)
print(f'The correlation coefficient between cloudiness and latitude is: {corr_cloud_s}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between cloudiness and latitude is: (0.17673806847476436, 0.02273455913504466)

# %% [markdown]
# **Analysis:**
# > - From the plots `Northern Hemisphere - Cloudiness vs. Latitude` & `Southern Hemisphere - Cloudiness vs. Latitude`, we can find that there is not much strong relation between data.
# > - In the northern hemisphere, Cloudiness and latitude has a week positive correlation.
# > - In the souther hemisphere, Cloudiness and latitude has a week positive correlation.
# > - It concludes that Cloudiness and latitude are not correlated.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_wind_speed_y = weather_north_hemis_df['Wind Speed']

slope_nws,intercept_nws,rvalue_nws,pvalue_nws,stderr_nws = linregress(north_hemis_x,north_wind_speed_y)
regress_value_nws = north_hemis_x * slope_nws + intercept_nws
line_ws_eq = "y = " + str(round(slope_nws,2)) + "x + " + str(round(intercept_nws,2))

fig,ax7 = plt.subplots(1,1,figsize = (8,5))
ax7.scatter(north_hemis_x,north_wind_speed_y,label = "Datapoint",edgecolors = 'black')
ax7.plot(north_hemis_x,regress_value_nws,"--",color='r',label = "Linear regression:\n" + line_ws_eq)

ax7.set_title('Northern Hemisphere: Wind Speed (mph) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax7.set_xlabel('Latitude')
ax7.set_ylabel('Wind Speed (mph)')
ax7.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax7.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/north_hemis_lat_vs_windSpeed.png")
plt.show()
plt.tight_layout()

corr_wind_speed_n = pearsonr(north_hemis_x,north_wind_speed_y)
print(f'The correlation coefficient between wind speed and latitude is: {corr_wind_speed_n}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between wind speed and latitude is: (0.05362272431052793, 0.2834702735370496)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_wind_speed_y = weather_south_hemis_df['Wind Speed']

slope_sws,intercept_sws,rvalue_sws,pvalue_sws,stderr_sws = linregress(south_hemis_x,south_wind_speed_y)
regress_value_sws = south_hemis_x * slope_sws + intercept_sws
line_ws2_eq = "y = " + str(round(slope_sws,2)) + "x + " + str(round(intercept_sws,2))

fig,ax8 = plt.subplots(1,1,figsize = (8,5))
ax8.scatter(south_hemis_x,south_wind_speed_y,label = "Datapoint",edgecolors = 'black')
ax8.plot(south_hemis_x,regress_value_sws,"--",color='r',label = "Linear regression:\n" + line_ws2_eq)

ax8.set_title('Southern Hemisphere: Wind Speed (mph) Vs Latitude ('+ date.today().strftime("%m/%d/%y") + ')')
ax8.set_xlabel('Latitude')
ax8.set_ylabel('Wind Speed (mph)')
ax8.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
ax8.set_axisbelow(True)
plt.grid(color='gray', linestyle='dashed')

plt.savefig("Output Data/Images/south_hemis_lat_vs_windSpeed.png")
plt.show()
plt.tight_layout()

corr_wind_speed_s = pearsonr(south_hemis_x,south_cloud_y)
print(f'The correlation coefficient between wind speed and latitude is: {corr_wind_speed_s}')
# Out:
# <img src="data:image/png;base64,..." width="800">
# The correlation coefficient between wind speed and latitude is: (0.17673806847476436, 0.02273455913504466)

# %% [markdown]
# **Analysis:**
# > - From the plots `Northern Hemisphere - wind speed vs. Latitude` & `Southern Hemisphere - wind speed vs. Latitude`, we can find that there is not much strong relation between data.<br>
# > - In the northern hemisphere, wind speed and latitude has a week positive correlation.<br>
# > - In the souther hemisphere, wind speed and latitude has a week positive correlation.<br>
# > - It concludes that wind speed and latitude are not correlated.
